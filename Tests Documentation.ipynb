# %% [markdown]
# # Test Documentation

# %% [markdown]
# * This notebook has been created in order to document the tests of all requirements of the project

# %%
from IPython.display import Image

# %% [markdown]
# ## GET /people -> Array with all people

# %% [markdown]
# * Call Example:
#
# --> On the browser
#
# https://ljorge08-eval-prod.apigee.net/23people/people?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77
#
# --> On a Linux terminal
#
#  curl -v "https://ljorge08-eval-prod.apigee.net/23people/people?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77"

# %%
# Image with the answer of the WS
Image(filename = "C:/Users/l_jor/OneDrive/Documents/GitHub/Test_23People/WS/Test_23People/Test Images/Get all People.png")

# %% [markdown]
# ## GET /people/:nationalId --> Return a person by national id

# %% [markdown]
# ### Returns status 404 if person is not found.
#
# * Call Example -->
#
# --> On the browser
#
# https://ljorge08-eval-prod.apigee.net/23people/people/73854642?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77
#
# --> On a linux terminal
#
# curl -v "https://ljorge08-eval-prod.apigee.net/23people/people/73854642?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77"

# %%
# Image with the answer of the WS
Image(filename = "C:/Users/l_jor/OneDrive/Documents/GitHub/Test_23People/WS/Test_23People/Test Images/Get nationalID not found.png")

# %% [markdown]
# ### Return a person by national id
#
# --> On the browser
#
# https://ljorge08-eval-prod.apigee.net/23people/people/73854642-2?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77
#
# --> On a linux terminal
#
# curl -v "https://ljorge08-eval-prod.apigee.net/23people/people/73854642-2?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77"

# %%
# Image with the answer of the WS
Image(filename = "C:/Users/l_jor/OneDrive/Documents/GitHub/Test_23People/WS/Test_23People/Test Images/Get nationalID.png")

# %% [markdown]
# ## POST /people + json

# %% [markdown]
# ### Returns status 400 on validation error or when “Content-Type” header is not set as “application/json”.
#
# --> Request
#
# curl -X POST https://ljorge08-eval-prod.apigee.net/23people/people?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77 -d '{"nationalId":"33333333-3","name":"jorge","lastName":"rodriguez","age":"33","originPlanet":"Tierra","PictureURL":"https://randomuser.me/api/portraits/men/65.jpg"}' -v

# %%
# Image with the answer of the WS
Image(filename = "C:/Users/l_jor/OneDrive/Documents/GitHub/Test_23People/WS/Test_23People/Test Images/Post no header.png")

# %% [markdown]
# ### Create a person based on json payload. Returns status 201
#
# --> Request
#
# curl -X POST https://ljorge08-eval-prod.apigee.net/23people/people?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77 -H "Content-Type: application/json" -d '{"nationalId":"33333333-3","name":"jorge","lastName":"rodriguez","age":"33","originPlanet":"Tierra","PictureURL":"https://randomuser.me/api/portraits/men/65.jpg"}' -v

# %%
# Image with the answer of the WS
Image(filename = "C:/Users/l_jor/OneDrive/Documents/GitHub/Test_23People/WS/Test_23People/Test Images/Post OK.png")

# %% [markdown]
# ### Returns status 500 on every other error.
#
# --> Request (The request is created with an extisting user)
#
# curl -X POST https://ljorge08-eval-prod.apigee.net/23people/people?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77 -H "Content-Type: application/json" -d '{"nationalId":"33333333-3","name":"jorge","lastName":"rodriguez","age":"33","originPlanet":"Tierra","PictureURL":"https://randomuser.me/api/portraits/men/65.jpg"}' -v

# %%
# Image with the answer of the WS
Image(filename = "C:/Users/l_jor/OneDrive/Documents/GitHub/Test_23People/WS/Test_23People/Test Images/Post no OK.png")

# %% [markdown]
# ## PUT /people/:id + json --> Updates a person based on national id and a json payload.

# %% [markdown]
# ### Returns status 200 on success.
#
# --> Request
#
# curl -X PUT https://ljorge08-eval-prod.apigee.net/23people/people/73854642-2?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77 -H "Content-Type: application/json" -H "apikey: 4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77" -d '{"name":"Blanca","lastName":"Bustos","age":"45","originPlanet":"Tierra","PictureURL":"https://randomuser.me/api/portraits/women/65.jpg"}' -v

# %%
# Image with the answer of the WS
Image(filename = "C:/Users/l_jor/OneDrive/Documents/GitHub/Test_23People/WS/Test_23People/Test Images/PUT OK.png")

# %% [markdown]
# ### Return status 404 if person is not found
#
# --> Request
#
# curl -X PUT https://ljorge08-eval-prod.apigee.net/23people/people/73854642?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77 -H "Content-Type: application/json" -H "apikey: 4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77" -d '{"name":"Sara","lastName":"Garzon","age":"34","originPlanet":"Tierra","PictureURL":"https://randomuser.me/api/portraits/women/65.jpg"}' -v

# %%
# Image with the answer of the WS
Image(filename = "C:/Users/l_jor/OneDrive/Documents/GitHub/Test_23People/WS/Test_23People/Test Images/PUT NOT FOUND.png")

# %% [markdown]
# ## Returns status 400 on validation error or when “Content-Type” header is not set as “application/json”.
#
# --> Request
#
# curl -X PUT https://ljorge08-eval-prod.apigee.net/23people/people/73854642?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77 -H "apikey: 4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77" -d '{"name":"Sara","lastName":"Garzon","age":"34","originPlanet":"Tierra","PictureURL":"https://randomuser.me/api/portraits/women/65.jpg"}' -v

# %%
# Image with the answer of the WS
Image(filename = "C:/Users/l_jor/OneDrive/Documents/GitHub/Test_23People/WS/Test_23People/Test Images/PUT not header.png")

# %% [markdown]
# ## DELETE /people/:id -> Deletes a person based on national id.

# %% [markdown]
# ### Returns status 200 on success.
#
# --> Request
#
# curl -X DELETE https://ljorge08-eval-prod.apigee.net/23people/people/33333333-3?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77 -v

# %%
# Image with the answer of the WS
Image(filename = "C:/Users/l_jor/OneDrive/Documents/GitHub/Test_23People/WS/Test_23People/Test Images/Delete OK.png")

# %% [markdown]
# ### Return status 404 when person is not found.
#
# --> Request
#
# curl -X DELETE https://ljorge08-eval-prod.apigee.net/23people/people/73854642?apikey=4Jy6ylxw6hIy7icA26HbWcGUvXKvVY77

# %%
# Image with the answer of the WS
Image(filename = "C:/Users/l_jor/OneDrive/Documents/GitHub/Test_23People/WS/Test_23People/Test Images/Delete No user.png")
